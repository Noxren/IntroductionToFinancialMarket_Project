# %%
import numpy as np
import pandas as pd

# %%
from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.runners import InMemoryRunner
from google.genai import types
from google.adk.sessions import InMemorySessionService
from google.adk.tools import google_search, AgentTool, ToolContext, FunctionTool
from google.adk.code_executors import BuiltInCodeExecutor
from google.adk.models.google_llm import Gemini

# %%
import APIKey    #Storing my API key in python class "APIKey"
import os

google_API = APIKey.GOOGLESTUDIO_API_KEY    #My google studio API

os.environ["GOOGLE_API_KEY"] = google_API

# %%
import yfinance as yf

# %%
google_news_agent = Agent(
    name="GoogleNewsAgent",
    model="gemini-2.5-flash",
    instruction="""You are a specialized news arrangement agent for a given company. 
    
    For a given company:
    1. Use 'google_search' to find the company's summary.
    2. Read the company's summary and then use 'google_search' to find current related news that would affect the company's stock price.
    3. Generate comment with important points and analysis about the company's stock future performance base on the news.
    """,
    tools = [google_search],
    output_key="google_news_arrangement",
)

# %%
def competitors_compare(target: str) -> dict:
    """Searching for the target company's main competitors and compare their main financial ratio.

    Args:
        taregt: The stock ticker of a company. It should be consisted of uppercase letters,
                e.g., "AAPL" or "NVDA".

    Returns:
        Dictionary with status and rate information.
        Success: {"status": "success", "comparison":
        | Ticker   |   Dividend Yield |   Trailing PE |   TTM PS |   Profit Margin |   PB Ratio |   
        Trailing EPS |   EV/EBITDA |   Current Ratio |   Debt-to-Equity |    ROA |    ROE |   PEG Ratio |\n|:---------|-----------------:|
        --------------:|---------:|----------------:|-----------:|---------------:|------------:|----------------:|-----------------:|-------:|
        -------:|------------:|\n| SHEL     |             3.8  |       15.3694 |   0.8023 |          0.0544 |     2.4892 |           4.9  |
        9.868 |           1.352 |           41.602 | 0.049  | 0.0815 |      1.634  |\n| XOM      |             3.5  |       17.3009 |   1.5554 |
        0.0918 |     1.9265 |           6.88 |       8.626 |           1.137 |           15.672 | 0.0511 | 0.1142 |      2.7756 |\n| CVX      |
        4.42 |       21.6062 |   1.6404 |          0.0677 |     1.6293 |           7.11 |       9.323 |           1.152 |           21.239 |
        0.0405 | 0.0732 |      2.9249 |\n| NFG      |             2.66 |       14.3187 |   3.2274 |          0.2277 |     2.3753 |           5.68 |
        7.132 |           0.444 |           91.548 | 0.0701 | 0.1745 |    N/A      |\n| UNTC     |            15.08 |        4.9303 |   1.3284 |
        0.2334 |     1.3559 |           6.74 |       2.907 |           3.545 |            1.009 | 0.15   | 0.2694 |    N/A      |}
        Error: {"status": "error", "error_message": "Stock ticker not found"}
    """

    metrics = ['dividendYield', 'trailingPE', 'priceToSalesTrailing12Months', 'profitMargins', 'priceToBook', 'trailingEps', 'enterpriseToEbitda', 
    'currentRatio', 'debtToEquity', 'returnOnAssets', 'returnOnEquity', 'trailingPegRatio']
    col_names = ['Ticker', 'Dividend Yield', 'Trailing PE', 'TTM PS', 'Profit Margin', 'PB Ratio', 'Trailing EPS', 'EV/EBITDA', 'Current Ratio',
               'Debt-to-Equity', 'ROA', 'ROE', 'PEG Ratio']
    
    ticker = yf.Ticker(target)
    info = ticker.info
    compare_df = pd.DataFrame(columns = col_names)
    
    industry = yf.Industry(info['industryKey'])
    competitors = list(industry.top_companies.index.values)
    competitors.insert(0, target)
    
    for comp in competitors:
        comp_info = yf.Ticker(comp).info
    
        row_data = [comp]
    
        for metric in metrics:
            value = comp_info.get(metric, 'NaN') 
            row_data.append(value)
    
        compare_df.loc[len(compare_df)] = row_data

    compare_df = compare_df.replace("NaN", np.nan)
    compare_df = compare_df.dropna(axis=1, how='all')
    compare_df = compare_df.fillna("N/A")

    compare_df = compare_df.round(4)
    compare_df_string = compare_df.to_markdown(index=False)

    if compare_df_string is not None:
        return {"status": "success", "comparison": compare_df_string}
    else:
        return {"status": "error", "error_message": f"Stock ticker '{target}' not found"}

# %%
competitors_agent = Agent(
    name="CompetitorsAgent",
    model="gemini-2.5-flash",
    instruction="""You are a specialized agent to compare the target company to its competitors.

    For a given company:
    1. Use 'competitors_compare' to get the target company and its main competitors' financial ratio data.
    2. Check the "status" field in it response for errors.
    3. Aanlyse the financial ratio data, summarize the most important points and provide some insights that might affect the target companies' 
    stock price.
    
    If any tool returns status "error", explain the issue to the user clearly.""",
    tools = [competitors_compare],
    output_key="comparing_competitors",
)

# %%
aggregator_agent = Agent(
    name="AggregatorAgent",
    model="gemini-2.5-flash-lite",
    instruction="""Combine these two analyses into a single investment memo:

    **News:**
    {google_news_arrangement}
    
    **Comparison:**
    {comparing_competitors}
    
    Your memo should highlight influences to the target stock price, recommendations, and the risk from these two analyses. The final summary should be around 200 words.""",
    output_key="investment_memo", # This will be the final output of the entire system.
)

# %%
parallel_analysis_team = ParallelAgent(
    name="ParallelAnalysisTeam",
    sub_agents=[google_news_agent, competitors_agent],
)

# This SequentialAgent defines the high-level workflow: run the parallel team first, then run the aggregator.
root_agent = SequentialAgent(
    name="AnalysisSystem",
    sub_agents=[parallel_analysis_team, aggregator_agent],
)

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("SHEL", verbose = True)
# Out:
#  ### Created new session: debug_session_id
#
# User > SHEL
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# CompetitorsAgent > [Calling tool: competitors_compare({'target': 'SHEL'})]
# C:\Users\User\AppData\Local\Temp\ipykernel_27472\337580190.py:46: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   compare_df.loc[len(compare_df)] = row_data
# C:\Users\User\AppData\Local\Temp\ipykernel_27472\337580190.py:46: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   compare_df.loc[len(compare_df)] = row_data
# C:\Users\User\AppData\Local\Temp\ipykernel_27472\337580190.py:46: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   compare_df.loc[len(compare_df)] = row_data
# C:\Users\User\AppData\Local\Temp\ipykernel_27472\337580190.py:48: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   compare_df = compare_df.replace("NaN", np.nan)
# CompetitorsAgent > [Tool result: {'status': 'success', 'comparison': '| Ticker   |   Dividend Yield | Trailing PE   |   TTM PS |   Pr...]
# CompetitorsAgent > SHEL's financial ratios present a mixed but insightful picture compared to its competitors.
#
# **Key Strengths:**
# *   **Valuation:** SHEL appears to be relatively undervalued based on its **Trailing PE (15.09)** and **TTM PS (0.7856)**, which are lower than major competitors like ExxonMobil (XOM) and Chevron (CVX). Its **PEG Ratio (1.6122)** is also more favorable than XOM and CVX, suggesting it might be reasonably priced relative to its growth prospects.
# *   **Liquidity:** SHEL boasts a healthy **Current Ratio (1.352)**, indicating good short-term financial health and ability to cover its immediate liabilities.
#
# **Areas for Improvement:**
# *   **Profitability and Efficiency:** SHEL's **Profit Margin (0.0544)**, **Trailing EPS (4.9)**, **ROA (0.049)**, and **ROE (0.0815)** are generally lower than several peers such as XOM, NFG, and UNTC. This suggests SHEL is less efficient at converting revenue into profit and generating returns from its assets and shareholders' equity.
# *   **Debt-to-Equity:** While not alarming, SHEL's **Debt-to-Equity ratio (41.602)** is higher than XOM and CVX, indicating a comparatively higher reliance on debt financing.
# *   **PB Ratio:** SHEL's **PB Ratio (2.4449)** is higher than most of its competitors, suggesting it trades at a higher multiple of its book value.
#
# **Insights that might affect SHEL's stock price:**
#
# *   **Potential for Valuation Upside (Positive):** The lower Trailing PE, TTM PS, and PEG ratios relative to key competitors like XOM and CVX suggest that SHEL might be undervalued by the market. If SHEL can demonstrate consistent performance or improvement in profitability, investors might re-rate its stock, leading to price appreciation.
# *   **Profitability Concerns Could Limit Growth (Negative):** The consistently lower profit margins and returns on assets/equity could be a concern for investors. Lower profitability may signal operational inefficiencies or competitive pressures that could hinder future earnings growth and dividend increases. This might cap the stock's upside potential unless there are clear signs of improving operational efficiency.
# *   **Stable Dividend Provides Support (Neutral/Positive):** A decent **Dividend Yield (3.84%)** can attract income-focused investors and provide some stability to the stock price. However, it's not the highest among its peers, so it may not be a primary driver for significant stock price growth.
# *   **Healthy Liquidity and Manageable Debt (Positive):** Good short-term liquidity and a moderate debt level contribute to financial stability, which is generally viewed favorably by investors and can provide a cushion during economic downturns, potentially supporting the stock price.
#
# In summary, SHEL offers a potentially attractive valuation with solid liquidity. However, its stock price performance will likely be significantly influenced by its ability to improve profitability and efficiency, which currently lag behind several competitors. Investors will be closely watching for signs of operational enhancements that could translate into stronger earnings and higher returns.
# GoogleNewsAgent > Shell plc (SHEL) is currently navigating a complex energy landscape, with recent strategic shifts and market dynamics significantly influencing its near-term and long-term stock performance.
#
# **Company Summary:**
# Shell plc is a British multinational integrated oil and gas company, headquartered in London, UK. It operates across various segments including Upstream (exploration and production), Integrated Gas (Liquefied Natural Gas - LNG, Gas to Liquids - GTL), Downstream (refining, marketing of fuels and lubricants, petrochemicals), and Renewables and Energy Solutions (wind, solar, biofuels, electric vehicle charging, hydrogen, carbon capture). Shell is a globally integrated energy major with operations in over 70 countries and aims to become a net-zero emissions business by 2050.
#
# **Current News and Stock Impact Analysis:**
#
# 1.  **Strategic Pivot Towards Traditional Energy:** Shell is reportedly scaling back investments in offshore wind and restructuring its power division, signaling a renewed emphasis on traditional oil, gas, and biofuels, particularly LNG. This shift, announced in late 2024/early 2025, is attributed to challenging conditions in the renewables sector, such as soaring costs, supply chain disruptions, and rising interest rates, as well as investor pressure for higher returns.
#     *   **Impact:** This strategic re-focus is likely to enhance Shell's profitability in the short to medium term by concentrating on its core, higher-margin businesses. However, it may attract criticism regarding its commitment to energy transition and expose the company to long-term risks associated with climate change policies and the potential for "stranded assets."
#
# 2.  **Continued Investment in Fossil Fuels:** Reports from activist groups indicate that Shell continues to allocate a significant portion of its investments (8-12% in Renewables and Energy Solutions in 2024) towards fossil fuel expansion, with plans for substantial new oil and gas projects. This approach has drawn criticism for potentially conflicting with Shell's net-zero targets and the Paris Climate Agreement, which calls for substantial emission reductions by 2030.
#     *   **Impact:** Aggressive fossil fuel investment, while potentially lucrative in the current energy market, could lead to increased regulatory scrutiny, environmental liabilities, and reputational damage in the long run. It also presents a risk of "carbon lock-in," making it harder for Shell to pivot to renewables in the future.
#
# 3.  **Geopolitical Tensions and Oil Prices:** Ongoing geopolitical tensions, particularly in the Middle East (e.g., Israel-Iran conflict and potential disruptions in the Strait of Hormuz), are expected to keep oil prices elevated. Shell, as a major global oil and gas producer with robust offshore operations and low breakeven costs, is strategically positioned to benefit from these higher prices and potential supply disruptions.
#     *   **Impact:** Elevated oil and gas prices due to geopolitical instability are a significant tailwind for Shell's earnings and cash flow, bolstering its financial performance and shareholder returns in the current environment.
#
# 4.  **Strong LNG Market Outlook:** Shell's internal scenarios project a bright future for natural gas and LNG, with demand potentially rising through the mid-2040s, driven by economic growth and increasing energy security concerns, especially in Asian markets. Shell is a dominant player in the global LNG market and is actively investing in infrastructure to capitalize on this growth.
#     *   **Impact:** The strong outlook for LNG provides a key growth driver and a relatively stable revenue stream for Shell, positioning it favorably in a market seeking cleaner-burning fossil fuels as a transition energy source.
#
# 5.  **Analyst Sentiment and Financial Performance:** Shell reported strong Q3 2025 results, outperforming expectations due to robust LNG performance and upstream output. JPMorgan recently reiterated a "Buy" rating and raised its target price for Shell. However, Bank of America downgraded Shell to "Neutral" in December 2025, citing limited valuation upside in a projected $60 Brent world for 2026 and uncertainty over the deployment of the company's substantial balance sheet headroom. Shell also recently completed debt exchange offers and acquired additional equity in Brazilian oil fields.
#     *   **Impact:** While recent financial results and some analyst upgrades suggest a positive outlook, concerns about future oil price stability and the strategic use of capital could temper some bullish sentiment. The company's ability to maintain strong shareholder returns (dividends and buybacks) remains a key focus.
#
# **Comment on Future Stock Performance:**
#
# Shell plc's stock performance in the **short to medium term (1-3 years)** is likely to be robust. The company's strategic pivot back to its highly profitable oil, gas, and LNG segments, combined with ongoing geopolitical tensions that are expected to sustain elevated energy prices, will likely drive strong earnings and cash flow. Shell's dominant position in the growing LNG market and disciplined cost management further support a positive outlook. Shareholder returns through dividends and buybacks are expected to remain attractive.
#
# However, the **long-term (3+ years)** outlook for Shell faces greater uncertainty. The continued heavy investment in fossil fuels, despite a stated net-zero ambition and warnings from groups about "stranded assets" and climate liabilities, poses significant risks. If global energy transition accelerates faster than anticipated, or if stricter environmental regulations and carbon pricing mechanisms are implemented, Shell could face increased financial and reputational headwinds. The IEA's forecast of declining oil and gas demand post-2029 also highlights the need for substantial diversification. While Shell is investing in renewables, the scale of these investments relative to its fossil fuel commitments raises questions about its long-term competitive positioning in a decarbonizing world. Investors seeking long-term growth and alignment with sustainability goals may view this as a significant concern.
# AggregatorAgent > ## Investment Memo: Shell plc (SHEL)
#
# **Date:** October 26, 2023
#
# **Subject:** Analysis of Shell plc (SHEL) Stock Performance and Investment Recommendation
#
# **Executive Summary:**
#
# Shell plc (SHEL) is navigating a dynamic energy landscape with a strategic shift towards traditional, higher-margin oil, gas, and LNG segments, while scaling back on some renewable energy investments. This pivot, coupled with sustained geopolitical tensions likely to keep energy prices elevated, positions Shell for robust short-to-medium term (1-3 years) financial performance and attractive shareholder returns. However, the company's continued substantial investment in fossil fuels, despite net-zero ambitions, introduces significant long-term risks related to climate policy, regulatory scrutiny, and potential "stranded assets." While Shell's valuation appears attractive relative to some peers, its profitability metrics lag, suggesting potential operational efficiency improvements could further unlock value.
#
# **Company Overview:**
#
# Shell plc is a global integrated energy major with operations spanning exploration and production (Upstream), Liquefied Natural Gas (LNG) and Gas to Liquids (GTL) (Integrated Gas), refining and marketing (Downstream), and Renewables and Energy Solutions. The company is committed to achieving net-zero emissions by 2050.
#
# **Analysis of Current News and Stock Impact:**
#
# 1.  **Strategic Pivot to Traditional Energy:** Shell's decision to reduce offshore wind investments and restructure its power division, favoring oil, gas, and LNG, is expected to boost short-to-medium term profitability. This focus leverages core strengths and potentially higher margins. However, it raises concerns about its commitment to the energy transition and exposes it to long-term climate policy risks.
#
# 2.  **Continued Fossil Fuel Investment:** Reports indicate significant ongoing investment in new oil and gas projects, which may conflict with net-zero targets. While potentially profitable in the near term, this strategy invites increased regulatory scrutiny, environmental liabilities, and reputational damage, potentially hindering future decarbonization efforts.
#
# 3.  **Geopolitical Tensions and Elevated Oil Prices:** Current geopolitical instability, particularly in the Middle East, is supporting higher oil and gas prices. Shell's operational efficiency and low breakeven costs position it favorably to capitalize on these elevated prices, driving strong earnings and cash flow.
#
# 4.  **Strong LNG Market Outlook:** Shell anticipates continued growth in natural gas and LNG demand through the mid-2040s, driven by economic development and energy security concerns. As a market leader, Shell is well-positioned to benefit from this trend, offering a stable revenue stream.
#
# 5.  **Analyst Sentiment and Financial Performance:** Recent strong Q3 2025 results, driven by LNG and upstream performance, have led to positive analyst sentiment, with JPMorgan reiterating a "Buy." However, Bank of America's "Neutral" downgrade highlights concerns about future oil price stability and capital deployment strategy. Shell's completion of debt exchanges and acquisition of Brazilian oil field equity are also noteworthy financial maneuvers.
#
# **Financial Ratios and Competitive Landscape:**
#
# Shell exhibits attractive valuation metrics, with a lower Trailing PE (15.09) and TTM PS (0.7856) compared to peers like ExxonMobil (XOM) and Chevron (CVX), suggesting potential undervaluation. Its Current Ratio (1.352) indicates healthy liquidity. However, its Profit Margin (0.0544), ROA (0.049), and ROE (0.0815) are lower than several competitors, pointing to areas for improved efficiency. The Debt-to-Equity ratio (41.602) is manageable but higher than some peers.
#
# **Future Stock Performance Outlook:**
#
# *   **Short to Medium Term (1-3 Years):** Shell's stock performance is expected to be robust. The strategic focus on profitable oil, gas, and LNG, combined with favorable geopolitical tailwinds for energy prices and a strong LNG outlook, should drive solid earnings and cash flow. Attractive shareholder returns via dividends and buybacks are anticipated.
#
# *   **Long Term (3+ Years):** The long-term outlook carries greater uncertainty. Continued substantial investment in fossil fuels, while potentially profitable in the interim, poses significant risks if the global energy transition accelerates or regulatory environments tighten. "Stranded asset" risk and reputational challenges are real concerns. While Shell is investing in renewables, the scale relative to fossil fuel commitments raises questions about its future competitive positioning in a decarbonizing world.
#
# **Recommendation:**
#
# **Consider a "Buy" for short-to-medium term exposure, with a focus on capital appreciation driven by current energy market dynamics and attractive dividend yields. However, exercise caution for long-term investments due to significant energy transition risks and the company's heavy reliance on fossil fuels.**
#
# **Risks:**
#
# *   **Energy Transition Risk:** A faster-than-expected global shift to renewables could diminish demand for Shell's core products, leading to asset write-downs and reduced profitability.
# *   **Regulatory and Policy Risk:** Increased environmental regulations, carbon pricing, and stricter climate policies could significantly impact Shell's operations and financial performance.
# *   **Geopolitical Volatility:** While currently a tailwind, sudden resolutions to geopolitical conflicts could lead to sharp declines in energy prices, negatively impacting Shell's earnings.
# *   **Execution Risk:** Failure to improve profitability and operational efficiency relative to peers could limit upside potential and shareholder returns.
# *   **Reputational Risk:** Continued heavy fossil fuel investment may lead to sustained criticism from environmental groups and impact brand image.
#
# **Conclusion:**
#
# Shell plc presents a compelling short-to-medium term investment opportunity, buoyed by a strategic focus on its core, profitable segments and favorable external market conditions. The company is poised to deliver strong financial results and shareholder returns in the near future. However, investors must weigh these near-term benefits against the considerable long-term uncertainties stemming from the global energy transition and Shell's ongoing commitment to fossil fuel expansion. The company's ability to effectively manage these divergent strategic imperatives and improve operational efficiency will be critical for its long-term success and stock performance.
