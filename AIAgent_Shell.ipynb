# %%
import pandas as pd
import numpy as np

# %%
#pip install google-adk
from google.adk.agents import Agent
from google.adk.runners import InMemoryRunner
from google.adk.tools import google_search
from google.genai import types

# %%
import APIKey    #Storing my API key in python class "APIKey"
import os

google_API = APIKey.GOOGLESTUDIO_API_KEY    #My google studio API

os.environ["GOOGLE_API_KEY"] = google_API

# %%
import yfinance as yf

ticker = "SHEL"
shell = yf.Ticker(ticker)

shell_stock_price = yf.download(ticker, period = "5y", auto_adjust=False)
shell_stock_price
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price       Adj Close      Close       High        Low       Open   Volume
# Ticker           SHEL       SHEL       SHEL       SHEL       SHEL     SHEL
# Date
# 2020-11-19  27.532658  33.180000  33.224998  32.480000  32.660000  4333768
# 2020-11-20  27.930962  33.660000  33.709999  33.165001  33.380001  4869829
# 2020-11-23  29.217140  35.209999  35.220001  34.619999  34.669998  6213612
# 2020-11-24  30.793758  37.110001  37.224998  36.744999  36.849998  7285970
# 2020-11-25  30.154818  36.340000  36.599998  35.810001  36.340000  5255506
# ...               ...        ...        ...        ...        ...      ...
# 2025-11-12  75.689377  76.410004  76.785004  76.370003  76.370003  3912880
# 2025-11-13  75.203995  75.919998  76.820000  75.665001  76.440002  4360533
# 2025-11-14  75.760002  75.760002  75.879997  74.870003  74.970001  4219442
# 2025-11-17  75.400002  75.400002  75.949997  75.080002  75.379997  4277056
# 2025-11-18  75.309998  75.309998  75.519997  74.010002  74.160004  5204714
#
# [1255 rows x 6 columns]

# %% [markdown]
# # Info

# %%
info = shell.info
info
# Out:
# {'address1': 'Shell Centre',
#  'city': 'London',
#  'zip': 'SE1 7NA',
#  'country': 'United Kingdom',
#  'phone': '44 20 7934 1234',
#  'website': 'https://www.shell.com',
#  'industry': 'Oil & Gas Integrated',
#  'industryKey': 'oil-gas-integrated',
#  'industryDisp': 'Oil & Gas Integrated',
#  'sector': 'Energy',
#  'sectorKey': 'energy',
#  'sectorDisp': 'Energy',
#  'longBusinessSummary': 'Shell plc operates as an energy and petrochemical company Europe, Asia, Oceania, Africa, the United States, and other Americas. It operates through Integrated Gas; Upstream; Marketing; Chemicals and Products; and Renewables and Energy Solutions segments. The company explores for and extracts natural gas to produce liquefied natural gas or convert into gas-to-liquids products; explores for and extracts crude oil and natural gas liquids; and operates upstream and midstream infrastructure to deliver gas to market. It is also involved in marketing supplies fuels and lubricants for transport, manufacturing, mining, power generation, agriculture, and construction industries; operates electric vehicle charging and convenience retail; turn crude oil and other feedstocks into products for households, industry, and transport; trades crude oil, oil products, and petrochemicals; and oil sand activities. In addition, the company generates, markets, and trades power from wind, solar and pipeline gas; hydrogen production and marketing; commercial carbon capture and storage hubs; carbon credits and nature-based solutions; and provides heavy-duty LNG-fuelled trucks. Further, it offers base chemicals, including ethylene, propylene, and aromatics, as well as intermediate chemicals, such as styrene monomer, propylene oxide, solvents, linear alpha olefins, detergent alcohols, ethylene oxide, ethylene glycol, and polyethylene. The company was formerly known as Royal Dutch Shell plc and changed its name to Shell plc in January 2022. Shell plc was founded in 1897 and is headquartered in London, the United Kingdom.',
#  'fullTimeEmployees': 96000,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Wael  Sawan',
#    'age': 50,
#    'title': 'CEO & Director',
#    'yearBorn': 1974,
#    'fiscalYear': 2024,
#    'totalPay': 6205549,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Sinead  Gorman',
#    'age': 47,
#    'title': 'CFO & Director',
#    'yearBorn': 1977,
#    'fiscalYear': 2024,
#    'totalPay': 4098873,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Robin  Mooldijk',
#    'age': 57,
#    'title': 'President of Projects & Technology',
#    'yearBorn': 1967,
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Philippa  Bounds',
#    'age': 53,
#    'title': 'Chief Legal Officer',
#    'yearBorn': 1971,
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Rachel  Solway',
#    'age': 50,
#    'title': 'Chief Human Resources & Corporate Officer',
#    'yearBorn': 1974,
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': "Mr. Graham Robert van't Hoff",
#    'age': 62,
#    'title': 'Executive Vice President of Chemicals',
#    'yearBorn': 1962,
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Stephanie  Boyde',
#    'title': 'Executive VP of Remuneration & HR Operations',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Brian Paul Eggleston',
#    'title': 'Executive Vice President of Finance Downstream',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Frank Hendrikus Lemmink',
#    'age': 56,
#    'title': 'Executive Vice President of Finance Integrated Gas, Renewables & Energy Solutions',
#    'yearBorn': 1968,
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Roland  Ilube',
#    'title': 'Senior Vice President of Finance Mobility',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'compensationAsOfEpochDate': 1735603200,
#  'irWebsite': 'http://www.shell.com/home/content/investor/',
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 75.4,
#  'open': 74.16,
#  'dayLow': 74.01,
#  'dayHigh': 75.52,
#  'regularMarketPreviousClose': 75.4,
#  'regularMarketOpen': 74.16,
#  'regularMarketDayLow': 74.01,
#  'regularMarketDayHigh': 75.52,
#  'dividendRate': 2.86,
#  'dividendYield': 3.8,
#  'exDividendDate': 1763078400,
#  'payoutRatio': 0.5788,
#  'fiveYearAvgDividendYield': 3.66,
#  'beta': -0.094,
#  'trailingPE': 15.369387,
#  'forwardPE': 9.581425,
#  'volume': 5191620,
#  'regularMarketVolume': 5204714,
#  'averageVolume': 4017874,
#  'averageVolume10days': 4043817,
#  'averageDailyVolume10Day': 4043817,
#  'bid': 75.43,
#  'ask': 75.44,
#  'bidSize': 1300,
#  'askSize': 200,
#  'marketCap': 215871275008,
#  'fiftyTwoWeekLow': 58.545,
#  'fiftyTwoWeekHigh': 77.47,
#  'allTimeHigh': 88.73,
#  'allTimeLow': 2.945,
#  'priceToSalesTrailing12Months': 0.8022717,
#  'fiftyDayAverage': 73.4554,
#  'twoHundredDayAverage': 70.19015,
#  'trailingAnnualDividendRate': 1.432,
#  'trailingAnnualDividendYield': 0.018992042,
#  'currency': 'USD',
#  'tradeable': False,
#  'enterpriseValue': 481105018880,
#  'profitMargins': 0.054380003,
#  'floatShares': 5660218975,
#  'sharesOutstanding': 2866435884,
#  'sharesShort': 11040431,
#  'sharesShortPriorMonth': 9026261,
#  'sharesShortPreviousMonthDate': 1759190400,
#  'dateShortInterest': 1761868800,
#  'sharesPercentSharesOut': 0.0038,
#  'heldPercentInsiders': 2.0000001e-05,
#  'heldPercentInstitutions': 0.12788,
#  'shortRatio': 2.67,
#  'shortPercentOfFloat': 0.0068,
#  'impliedSharesOutstanding': 2866435884,
#  'bookValue': 30.255,
#  'priceToBook': 2.4891753,
#  'lastFiscalYearEnd': 1735603200,
#  'nextFiscalYearEnd': 1767139200,
#  'mostRecentQuarter': 1759190400,
#  'earningsQuarterlyGrowth': 0.24,
#  'netIncomeToCommon': 14631000064,
#  'trailingEps': 4.9,
#  'forwardEps': 7.86,
#  'lastSplitFactor': '4:1',
#  'lastSplitDate': 867628800,
#  'enterpriseToRevenue': 1.788,
#  'enterpriseToEbitda': 9.868,
#  '52WeekChange': 0.14572251,
#  'SandP52WeekChange': 0.1276716,
#  'lastDividendValue': 0.716,
#  'lastDividendDate': 1763078400,
#  'quoteType': 'EQUITY',
#  'currentPrice': 75.31,
#  'targetHighPrice': 91.0,
#  'targetLowPrice': 78.0,
#  'targetMeanPrice': 83.2375,
#  'targetMedianPrice': 80.5,
#  'recommendationMean': 2.05556,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 16,
#  'totalCash': 33052999680,
#  'totalCashPerShare': 5.688,
#  'ebitda': 48754999296,
#  'totalDebt': 73977004032,
#  'quickRatio': 0.874,
#  'currentRatio': 1.352,
#  'totalRevenue': 269075005440,
#  'debtToEquity': 41.602,
#  'revenuePerShare': 89.794,
#  'returnOnAssets': 0.04901,
#  'returnOnEquity': 0.081549995,
#  'grossProfits': 68465000448,
#  'freeCashflow': 17617500160,
#  'operatingCashflow': 46590001152,
#  'earningsGrowth': 0.324,
#  'revenueGrowth': -0.041,
#  'grossMargins': 0.25445,
#  'ebitdaMargins': 0.18119,
#  'operatingMargins': 0.11347,
#  'financialCurrency': 'USD',
#  'symbol': 'SHEL',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Nasdaq Real Time Price',
#  'triggerable': True,
#  'customPriceAlertConfidence': 'HIGH',
#  'postMarketPrice': 75.15,
#  'postMarketChange': -0.15999603,
#  'regularMarketChange': -0.090004,
#  'regularMarketDayRange': '74.01 - 75.52',
#  'fullExchangeName': 'NYSE',
#  'averageDailyVolume3Month': 4017874,
#  'fiftyTwoWeekLowChange': 16.765,
#  'fiftyTwoWeekLowChangePercent': 0.28636092,
#  'fiftyTwoWeekRange': '58.545 - 77.47',
#  'fiftyTwoWeekHighChange': -2.1600037,
#  'fiftyTwoWeekHighChangePercent': -0.027881807,
#  'fiftyTwoWeekChangePercent': 14.57225,
#  'dividendDate': 1766016000,
#  'earningsTimestamp': 1761827400,
#  'earningsTimestampStart': 1761827400,
#  'earningsTimestampEnd': 1761827400,
#  'earningsCallTimestampStart': 1761834600,
#  'earningsCallTimestampEnd': 1761834600,
#  'isEarningsDateEstimate': False,
#  'epsTrailingTwelveMonths': 4.9,
#  'epsForward': 7.86,
#  'epsCurrentYear': 6.52979,
#  'priceEpsCurrentYear': 11.533296,
#  'fiftyDayAverageChange': 1.854599,
#  'fiftyDayAverageChangePercent': 0.025247961,
#  'twoHundredDayAverageChange': 5.11985,
#  'twoHundredDayAverageChangePercent': 0.07294258,
#  'sourceInterval': 15,
#  'exchangeDataDelayedBy': 0,
#  'prevName': 'Royal Dutch Shell plc',
#  'nameChangeDate': '2025-11-17',
#  'averageAnalystRating': '2.1 - Buy',
#  'corporateActions': [],
#  'postMarketTime': 1763505401,
#  'regularMarketTime': 1763499602,
#  'exchange': 'NYQ',
#  'messageBoardId': 'finmb_22385966',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EST',
#  'gmtOffSetMilliseconds': -18000000,
#  'market': 'us_market',
#  'esgPopulated': False,
#  'regularMarketChangePercent': -0.119369,
#  'regularMarketPrice': 75.31,
#  'marketState': 'POST',
#  'cryptoTradeable': False,
#  'shortName': 'Shell PLC',
#  'longName': 'Shell plc',
#  'hasPrePostMarketData': True,
#  'firstTradeDateMilliseconds': 447949800000,
#  'postMarketChangePercent': -0.21244992,
#  'displayName': 'Shell',
#  'trailingPegRatio': 1.634}

# %%
# Using summary as part of the Ai prompt
summary = info['longBusinessSummary']
summary
# Out:
# 'Shell plc operates as an energy and petrochemical company Europe, Asia, Oceania, Africa, the United States, and other Americas. It operates through Integrated Gas; Upstream; Marketing; Chemicals and Products; and Renewables and Energy Solutions segments. The company explores for and extracts natural gas to produce liquefied natural gas or convert into gas-to-liquids products; explores for and extracts crude oil and natural gas liquids; and operates upstream and midstream infrastructure to deliver gas to market. It is also involved in marketing supplies fuels and lubricants for transport, manufacturing, mining, power generation, agriculture, and construction industries; operates electric vehicle charging and convenience retail; turn crude oil and other feedstocks into products for households, industry, and transport; trades crude oil, oil products, and petrochemicals; and oil sand activities. In addition, the company generates, markets, and trades power from wind, solar and pipeline gas; hydrogen production and marketing; commercial carbon capture and storage hubs; carbon credits and nature-based solutions; and provides heavy-duty LNG-fuelled trucks. Further, it offers base chemicals, including ethylene, propylene, and aromatics, as well as intermediate chemicals, such as styrene monomer, propylene oxide, solvents, linear alpha olefins, detergent alcohols, ethylene oxide, ethylene glycol, and polyethylene. The company was formerly known as Royal Dutch Shell plc and changed its name to Shell plc in January 2022. Shell plc was founded in 1897 and is headquartered in London, the United Kingdom.'

# %%
# Comparing some financial data with its competitors 
compare_df = pd.DataFrame(columns = ['Ticker', 'Dividend Yield', 'Trailing PE', 'TTM PS', 'Profit Margin', 'PB Ratio', 'Trailing EPS', 'EV/EBITDA', 
                                     'Current Ratio', 'Debt-to-Equity', 'ROA', 'ROE', 'PEG Ratio'])

shell_list = [ticker, info['dividendYield'], info['trailingPE'], info['priceToSalesTrailing12Months'], info['profitMargins'], info['priceToBook'], 
             info['trailingEps'], info['enterpriseToEbitda'], info['currentRatio'], info['debtToEquity'], info['returnOnAssets'],
             info['returnOnEquity'], info['trailingPegRatio']] 

compare_df.loc[0] = shell_list
compare_df
# Out:
#   Ticker  Dividend Yield  Trailing PE    TTM PS  Profit Margin  PB Ratio  \
# 0   SHEL             3.8    15.369387  0.802272        0.05438  2.489175
#
#    Trailing EPS  EV/EBITDA  Current Ratio  Debt-to-Equity      ROA      ROE  \
# 0           4.9      9.868          1.352          41.602  0.04901  0.08155
#
#    PEG Ratio
# 0      1.634

# %%
# Find the companies' main competitors
industry = yf.Industry(info['industryKey'])

competitors = list(industry.top_companies.index.values)
competitors
# Out:
# ['XOM', 'CVX', 'NFG', 'UNTC']

# %%
# Adding the competitors' financial data to make comparison
for comp in competitors:
    comp_info = yf.Ticker(comp).info
    comp_list = [comp, comp_info['dividendYield'], comp_info['trailingPE'], comp_info['priceToSalesTrailing12Months'], comp_info['profitMargins'],
                 comp_info['priceToBook'], comp_info['trailingEps'], comp_info['enterpriseToEbitda'], comp_info['currentRatio'], 
                 comp_info['debtToEquity'], comp_info['returnOnAssets'], comp_info['returnOnEquity'], comp_info['trailingPegRatio']]
    compare_df.loc[len(compare_df)] = comp_list

compare_df
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15808\820696664.py:7: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   compare_df.loc[len(compare_df)] = comp_list
# C:\Users\User\AppData\Local\Temp\ipykernel_15808\820696664.py:7: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   compare_df.loc[len(compare_df)] = comp_list
#   Ticker  Dividend Yield  Trailing PE    TTM PS  Profit Margin  PB Ratio  \
# 0   SHEL            3.80    15.369387  0.802272        0.05438  2.489175
# 1    XOM            3.50    17.300870  1.555439        0.09181  1.926488
# 2    CVX            4.42    21.606188  1.640373        0.06767  1.629333
# 3    NFG            2.66    14.318663  3.227398        0.22766  2.375292
# 4   UNTC           15.08     4.930267  1.328413        0.23337  1.355939
#
#    Trailing EPS  EV/EBITDA  Current Ratio  Debt-to-Equity      ROA      ROE  \
# 0          4.90      9.868          1.352          41.602  0.04901  0.08155
# 1          6.88      8.626          1.137          15.672  0.05108  0.11424
# 2          7.11      9.323          1.152          21.239  0.04047  0.07316
# 3          5.68      7.132          0.444          91.548  0.07008  0.17449
# 4          6.74      2.907          3.545           1.009  0.14997  0.26941
#
#    PEG Ratio
# 0     1.6340
# 1     2.7756
# 2     2.9249
# 3        NaN
# 4        NaN

# %%
# Round the number for a more effective AI agent
compare_df = compare_df.round(4)

# Convert the dataframe to string for AI prompt
compare_df_string = compare_df.to_markdown(index=False)
compare_df_string
# Out:
# '| Ticker   |   Dividend Yield |   Trailing PE |   TTM PS |   Profit Margin |   PB Ratio |   Trailing EPS |   EV/EBITDA |   Current Ratio |   Debt-to-Equity |    ROA |    ROE |   PEG Ratio |\n|:---------|-----------------:|--------------:|---------:|----------------:|-----------:|---------------:|------------:|----------------:|-----------------:|-------:|-------:|------------:|\n| SHEL     |             3.8  |       15.3694 |   0.8023 |          0.0544 |     2.4892 |           4.9  |       9.868 |           1.352 |           41.602 | 0.049  | 0.0815 |      1.634  |\n| XOM      |             3.5  |       17.3009 |   1.5554 |          0.0918 |     1.9265 |           6.88 |       8.626 |           1.137 |           15.672 | 0.0511 | 0.1142 |      2.7756 |\n| CVX      |             4.42 |       21.6062 |   1.6404 |          0.0677 |     1.6293 |           7.11 |       9.323 |           1.152 |           21.239 | 0.0405 | 0.0732 |      2.9249 |\n| NFG      |             2.66 |       14.3187 |   3.2274 |          0.2277 |     2.3753 |           5.68 |       7.132 |           0.444 |           91.548 | 0.0701 | 0.1745 |    nan      |\n| UNTC     |            15.08 |        4.9303 |   1.3284 |          0.2334 |     1.3559 |           6.74 |       2.907 |           3.545 |            1.009 | 0.15   | 0.2694 |    nan      |'

# %% [markdown]
# # News AI Agent
# ### With news generate by google search

# %%
google_news_agent = Agent(
    name="GoogleNewsAgent",
    model="gemini-2.5-flash",
    instruction="""You are a specialized news arrange agent for a given company. Your job is to read the company's summary and use Google Search 
    to find news relate to the company and generate comment with some important points that might affect the company's stock price.""",
    tools = [google_search],
    output_key="google_news_arrangement",
)

# %%
runner = InMemoryRunner(agent=google_news_agent)
prompt = f"""{ticker} summary: 

{summary}"""
response = await runner.run_debug(prompt)
# Out:
#  ### Created new session: debug_session_id
#
# User > SHEL summary:
#
# Shell plc operates as an energy and petrochemical company Europe, Asia, Oceania, Africa, the United States, and other Americas. It operates through Integrated Gas; Upstream; Marketing; Chemicals and Products; and Renewables and Energy Solutions segments. The company explores for and extracts natural gas to produce liquefied natural gas or convert into gas-to-liquids products; explores for and extracts crude oil and natural gas liquids; and operates upstream and midstream infrastructure to deliver gas to market. It is also involved in marketing supplies fuels and lubricants for transport, manufacturing, mining, power generation, agriculture, and construction industries; operates electric vehicle charging and convenience retail; turn crude oil and other feedstocks into products for households, industry, and transport; trades crude oil, oil products, and petrochemicals; and oil sand activities. In addition, the company generates, markets, and trades power from wind, solar and pipeline gas; hydrogen production and marketing; commercial carbon capture and storage hubs; carbon credits and nature-based solutions; and provides heavy-duty LNG-fuelled trucks. Further, it offers base chemicals, including ethylene, propylene, and aromatics, as well as intermediate chemicals, such as styrene monomer, propylene oxide, solvents, linear alpha olefins, detergent alcohols, ethylene oxide, ethylene glycol, and polyethylene. The company was formerly known as Royal Dutch Shell plc and changed its name to Shell plc in January 2022. Shell plc was founded in 1897 and is headquartered in London, the United Kingdom.
# GoogleNewsAgent > Shell plc (SHEL) has been active across its diverse portfolio, with recent financial results showing overall strength despite some missed expectations, alongside strategic adjustments in its energy transition efforts and ongoing legal matters. These developments present a mixed but largely positive outlook for the company's stock.
#
# **Key Points Affecting Stock Price:**
#
# *   **Strong Q3 2025 Financial Performance (Positive):** Shell reported adjusted earnings of $5.4 billion in Q3 2025, an increase from $4.3 billion in Q2 2025, and generated $12.2 billion in cash flow from operations. Income attributable to shareholders also rose significantly to $5.3 billion. This strong operational performance, particularly in its Marketing business and deepwater assets, is likely to be viewed positively by investors.
# *   **Shareholder Returns - Buybacks and Dividends (Positive):** The company announced a new $3.5 billion share buyback program, marking its 16th consecutive quarter of buybacks exceeding $3 billion. Shell also declared a Q3 2025 dividend of $0.358 per share, with total shareholder distributions for the quarter reaching $5.7 billion. This consistent return of capital to shareholders typically underpins investor confidence.
# *   **Q3 2025 Earnings Per Share (EPS) and Revenue Miss (Potentially Negative):** Despite the overall strong adjusted earnings, Shell's Q3 EPS of $0.93 fell short of the $1.62 forecast, and revenue of $68.15 billion was slightly below expectations. While the stock remained relatively stable post-announcement, this miss could introduce some caution among investors regarding future profitability projections.
# *   **Capital Structure Optimization (Positive):** Shell is undertaking exchange offers to optimize its capital structure by moving existing debt from non-US entities to Shell Finance US. The early participation results show significant interest, and the extension of the Early Participation Premium aims to further enhance this process, suggesting improved financial efficiency.
# *   **Renewable Energy and Hydrogen Investments (Long-term Positive, Mixed Short-term):** Shell is progressing its renewable projects, including starting construction of a solar park in Italy and opening its largest solar park in Europe in the Netherlands. It has also acquired a solar platform in Spain and secured power purchase agreements in Germany for its REFHYNE 2 hydrogen electrolyzer, demonstrating a commitment to low-carbon solutions. However, the Renewables segment has continued to incur significant losses in the first nine months of 2025, following near break-even in 2024, which could temper enthusiasm for its green transition in the short term.
# *   **Offshore Wind Project Cancellations (Potentially Negative/Strategic Shift):** Shell has canceled plans for two offshore wind farms in Scotland and previously withdrew from the Atlantic Shores Offshore Wind project in the U.S. This is attributed to a strategic shift, with Shell focusing its power strategy on trading and integrated energy solutions rather than direct majority stakes in power generation assets. While a strategic realignment, it could be seen by some as a reduction in direct renewable energy development.
# *   **Investment in Nigerian Gas Project (Positive):** Shell has made a final investment decision for the $2 billion HI offshore gas project in Nigeria. This project is expected to significantly boost Nigeria's LNG export capacity, supplying 350 million standard cubic feet of gas per day to Nigeria LNG, which could enhance Shell's future revenue streams from its Integrated Gas segment.
# *   **LNG Arbitration Defeat (Negative):** Shell recently suffered an arbitration defeat against Venture Global, Inc. regarding LNG supply contracts, being ordered to cover legal fees. Shell is challenging this ruling in the New York Supreme Court, citing withheld evidence. This legal dispute could lead to financial liabilities and impact investor sentiment.
# *   **Continued Oil and Gas Expansion (Long-term Risk/Environmental Concern):** A March 2024 report highlighted Shell's continued expansion of oil and gas projects despite a 2021 court ruling to reduce emissions. This ongoing focus on fossil fuels, with 20 major projects approved since the ruling, including 6 in 2023, could expose Shell to continued environmental scrutiny, regulatory pressures, and potential legal challenges, affecting its ESG profile. Shell is also appealing a South African court ruling that blocked exploration.

# %% [markdown]
# # Comparing AI Agent

# %%
competitors_agent = Agent(
    name="CompetitorsAgent",
    model="gemini-2.5-flash",
    instruction="""You are a specialized agent to compare the target company to its competitors. Your job is to analyse the financial ratio for 
    the given company and its competitors. Finally summary the most important points and provide some insights that might affect the target 
    companies' stock price.""",
    output_key="comparing_competitors",
)

# %%
runner = InMemoryRunner(agent=competitors_agent)
prompt = f""" Please analyze the following financial data for SHEL and its competitors:

{compare_df_string}"""
response = await runner.run_debug(prompt)
# Out:
#  ### Created new session: debug_session_id
#
# User >  Please analyze the following financial data for SHEL and its competitors:
#
# | Ticker   |   Dividend Yield |   Trailing PE |   TTM PS |   Profit Margin |   PB Ratio |   Trailing EPS |   EV/EBITDA |   Current Ratio |   Debt-to-Equity |    ROA |    ROE |   PEG Ratio |
# |:---------|-----------------:|--------------:|---------:|----------------:|-----------:|---------------:|------------:|----------------:|-----------------:|-------:|-------:|------------:|
# | SHEL     |             3.8  |       15.3694 |   0.8023 |          0.0544 |     2.4892 |           4.9  |       9.868 |           1.352 |           41.602 | 0.049  | 0.0815 |      1.634  |
# | XOM      |             3.5  |       17.3009 |   1.5554 |          0.0918 |     1.9265 |           6.88 |       8.626 |           1.137 |           15.672 | 0.0511 | 0.1142 |      2.7756 |
# | CVX      |             4.42 |       21.6062 |   1.6404 |          0.0677 |     1.6293 |           7.11 |       9.323 |           1.152 |           21.239 | 0.0405 | 0.0732 |      2.9249 |
# | NFG      |             2.66 |       14.3187 |   3.2274 |          0.2277 |     2.3753 |           5.68 |       7.132 |           0.444 |           91.548 | 0.0701 | 0.1745 |    nan      |
# | UNTC     |            15.08 |        4.9303 |   1.3284 |          0.2334 |     1.3559 |           6.74 |       2.907 |           3.545 |            1.009 | 0.15   | 0.2694 |    nan      |
# CompetitorsAgent > The analysis of SHEL's financial ratios against its competitors (XOM, CVX, NFG, UNTC) reveals a mixed financial picture, highlighting areas of strength and notable weaknesses that could influence its stock price.
#
# **Summary of SHEL's Financial Position:**
#
# **Strengths:**
# *   **Valuation (Relative to Growth):** SHEL boasts the lowest PEG ratio (1.634) among its directly comparable integrated energy peers (XOM, CVX), suggesting it offers better value when considering its earnings growth prospects.
# *   **Valuation (Sales):** With a TTM P/S ratio of 0.8023, SHEL is trading at the lowest multiple of sales among all listed competitors, potentially indicating undervaluation on a revenue basis.
# *   **Liquidity:** Its Current Ratio of 1.352 is healthy and superior to that of XOM (1.137) and CVX (1.152), indicating strong short-term liquidity management.
# *   **Dividend Yield:** At 3.8%, SHEL offers a competitive dividend yield, comparable to or slightly better than XOM (3.5%), making it attractive to income-focused investors.
# *   **ROA:** SHEL's Return on Assets (4.9%) is competitive, outperforming CVX (4.05%) and only slightly trailing XOM (5.11%), suggesting decent asset utilization for profit generation.
#
# **Weaknesses:**
# *   **Profitability:** SHEL's Profit Margin of 5.44% is significantly lower than XOM (9.18%) and CVX (6.77%), and dramatically less than NFG (22.77%) and UNTC (23.34%). This is a major concern, indicating less efficient operations or a less profitable business mix.
# *   **Leverage:** The Debt-to-Equity ratio of 41.602% is considerably higher than XOM (15.672%) and CVX (21.239%), implying greater financial risk and less flexibility.
# *   **Valuation (Earnings & Enterprise Value):** While SHEL's Trailing PE (15.3694) is lower than XOM and CVX, its EV/EBITDA (9.868) is higher than both XOM (8.626) and CVX (9.323). This suggests that once debt and operating earnings are accounted for, SHEL might not be as cheap as its PE ratio implies. The PB Ratio (2.4892) is also higher than XOM and CVX, potentially indicating less tangible asset backing for its market value relative to peers.
# *   **Return on Equity:** SHEL's ROE of 8.15% trails XOM (11.42%) and NFG (17.45%), suggesting less efficient use of shareholder equity to generate profits.
# *   **Trailing EPS:** SHEL's EPS of $4.90 is lower than all listed competitors, including XOM ($6.88) and CVX ($7.11), which contributes to its lower market perception.
#
# *(Note: UNTC and NFG present somewhat different business models or unique financial characteristics, especially UNTC with extremely high dividend yield, low valuation multiples, and high profitability, which may skew direct comparisons as primary integrated oil and gas companies like SHEL, XOM, and CVX.)*
#
# **Insights Affecting SHEL's Stock Price:**
#
# 1.  **Profitability Discount:** The most significant concern for SHEL is its markedly lower profit margin. Investors typically reward companies with higher profitability, as it indicates efficient operations and strong pricing power. SHEL's inability to convert sales into profits as effectively as XOM and CVX could lead the market to apply a discount to its stock, capping its upside potential regardless of other seemingly "cheap" metrics like P/S or PEG. Any sustained improvement in profit margins would be a strong positive catalyst.
#
# 2.  **Leverage and Risk Perception:** A higher Debt-to-Equity ratio compared to its major peers increases SHEL's financial risk profile. This makes the company more vulnerable to economic downturns, higher interest rates, or operational disruptions. Risk-averse investors might shy away, and this increased perceived risk can weigh on the stock price. Reducing debt or demonstrating strong cash flow generation to comfortably service debt would be viewed favorably.
#
# 3.  **Mixed Valuation Signals:** While SHEL's low P/S and PEG ratios might attract value investors, the higher EV/EBITDA and P/B ratios, coupled with low profitability, suggest a more nuanced valuation story. The market seems to be pricing in the lower quality of earnings or the higher leverage. For the stock price to climb sustainably, investors would need clarity on how the company plans to align its underlying operational efficiency with its growth prospects.
#
# 4.  **Strategic Transition Impact:** Shell has been actively pursuing an energy transition strategy, moving towards lower-carbon businesses. While strategically sound for the long term, these new ventures may currently have lower profit margins or higher capital expenditure requirements, potentially contributing to the observed lower profitability and higher debt. Investors will be looking for signs that this transition can eventually deliver improved financial performance and higher returns, justifying the current trade-offs. Until then, uncertainty around this transition's financial success could temper stock price appreciation.
#
# 5.  **Dividend Sustainability vs. Growth:** SHEL's competitive dividend yield is attractive, but its lower profitability and higher debt compared to XOM suggest that future dividend growth might be more constrained. Investors seeking growing income streams might prefer peers with stronger underlying profitability and lower leverage, which could lead to more robust dividend growth.
#
# In conclusion, while SHEL offers some attractive valuation metrics (P/S, PEG) and a competitive dividend, these positives are largely overshadowed by its lower profit margins and higher financial leverage compared to its primary integrated oil and gas competitors. For SHEL's stock price to see significant appreciation, the company must demonstrate tangible progress in improving its operational efficiency, boosting profit margins, and managing its debt load effectively, particularly as it navigates its energy transition. Without these fundamental improvements, the market is likely to maintain a cautious stance, potentially limiting significant upward movement in its stock price.
